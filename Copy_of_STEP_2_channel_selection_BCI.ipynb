# %% [markdown]
# <a href="https://colab.research.google.com/github/dasparagjyoti/EEG-Channel-Selection-for-Emotion-Recognition/blob/main/Copy_of_STEP_2_channel_selection_BCI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest, SelectPercentile
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold 
from sklearn.neural_network import MLPClassifier
import warnings
warnings.filterwarnings("ignore")
# !pip install skfeature-chappers
drive._mount('/content/drive')
drive.mount('/content/drive', force_remount=True)

# %% [markdown]
# # Fisher Score

# %%
import numpy as np
from skfeature.utility.construct_W import construct_W
from scipy.sparse import diags
def fisher_score(X, y):
    """
    This function implements the fisher score feature selection, steps are as follows:
    1. Construct the affinity matrix W in fisher score way
    2. For the r-th feature, we define fr = X(:,r), D = diag(W*ones), ones = [1,...,1]', L = D - W
    3. Let fr_hat = fr - (fr'*D*ones)*ones/(ones'*D*ones)
    4. Fisher score for the r-th feature is score = (fr_hat'*D*fr_hat)/(fr_hat'*L*fr_hat)-1
    Input
    -----
    X: {numpy array}, shape (n_samples, n_features)
        input data
    y: {numpy array}, shape (n_samples,)
        input class labels
    Output
    ------
    score: {numpy array}, shape (n_features,)
        fisher score for each feature
    Reference
    ---------
    He, Xiaofei et al. "Laplacian Score for Feature Selection." NIPS 2005.
    Duda, Richard et al. "Pattern classification." John Wiley & Sons, 2012.
    """

    # Construct weight matrix W in a fisherScore way
    kwargs = {"neighbor_mode": "supervised", "fisher_score": True, 'y': y}
    W = construct_W(X, **kwargs)

    # build the diagonal D matrix from affinity matrix W
    D = np.array(W.sum(axis=1))
    L = W
    tmp = np.dot(np.transpose(D), X)
    D = diags(np.transpose(D), [0])
    Xt = np.transpose(X)
    t1 = np.transpose(np.dot(Xt, D.todense()))
    t2 = np.transpose(np.dot(Xt, L.todense()))
    # compute the numerator of Lr
    D_prime = np.sum(np.multiply(t1, X), 0) - np.multiply(tmp, tmp)/D.sum()
    # compute the denominator of Lr
    L_prime = np.sum(np.multiply(t2, X), 0) - np.multiply(tmp, tmp)/D.sum()
    # avoid the denominator of Lr to be 0
    D_prime[D_prime < 1e-12] = 10000
    lap_score = 1 - np.array(np.multiply(L_prime, 1/D_prime))[0, :]

    # compute fisher score from laplacian score, where fisher_score = 1/lap_score - 1
    score = 1.0/lap_score - 1
    return np.transpose(score)


def feature_ranking(score):
    """
    Rank features in descending order according to fisher score, the larger the fisher score, the more important the
    feature is
    """
    idx = np.argsort(score, 0)
    return idx[::-1]

# %%
def emotion_label(labels, class_label):
	em_labels = []
	if(class_label == "valence"):
		for i in range(0, labels.shape[0]):
			if (labels[i][0]>5): # high valence
				em_labels.append(1)
			else: # low valence
				em_labels.append(0)
		return em_labels
	elif(class_label == "arousal"):
		for i in range(0, labels.shape[0]):
			if (labels[i][1]>5): # high arousal
				em_labels.append(1)
			else: # low arousal
				em_labels.append(0)
		return em_labels
	elif(class_label == "all"):
		for i in range(0, labels.shape[0]):
			if (labels[i][0]>5): # high valence
				if(labels[i][1]>5): # high arousal
					em_labels.append(1) # HVHA
				else:
					em_labels.append(0) # HVLA
			else: # low valence
				if(labels[i][1]>5): # high arousal
					em_labels.append(2) # LVHA
				else: # low arousal
					em_labels.append(3) # LVLA
		return em_labels
	else:
		print("Wrong input has been given. Please try again with 'valence'/'arousal'/'all'\n")

# %%
def get_fisher_score(subject_name, em_labels):
  mypath = "/content/drive/MyDrive/Sequential methods for channel selection/our code/" + subject_name + "/" + subject_name
  # for theta band
  data_theta = pd.read_csv(mypath + '_theta.csv')
  X, y = np.array(data_theta), np.array(em_labels)
  f_score_theta = fisher_score(X, y)
  # for alpha band
  data_alpha = pd.read_csv(mypath + '_alpha.csv')
  X, y = np.array(data_alpha), np.array(em_labels)
  f_score_alpha = fisher_score(X, y)
  # for beta band
  data_beta = pd.read_csv(mypath + '_beta.csv')
  X, y = np.array(data_beta), np.array(em_labels)
  f_score_beta = fisher_score(X, y)
  # for gamma band
  data_gamma = pd.read_csv(mypath + '_gamma.csv')
  X, y = np.array(data_gamma), np.array(em_labels)
  f_score_gamma = fisher_score(X, y)
  # Total Avearge F-Score (Theta, Alpha, Beta, Gamma)
  final_f_score = (f_score_theta + f_score_alpha + f_score_beta + f_score_gamma)/4
  eeg_channels = np.array(["Fp1", "AF3", "F3", "F7", "FC5", "FC1", "C3", "T7", "CP5", "CP1", "P3", "P7", "PO3", "O1", "Oz", "Pz", "Fp2", "AF4", "Fz", "F4", "F8", "FC6", "FC2", "Cz", "C4", "T8", "CP6", "CP2", "P4", "P8", "PO4", "O2"])
  fvalues = pd.Series(final_f_score)
  fvalues.index = eeg_channels
  fvalues.sort_values(ascending=False)
  fvalues.to_csv('fscore_final.csv')
  #fvalues.sort_values(ascending = False).plot.bar(figsize=(10,8))
  shyam = fvalues.sort_values(ascending = False)
  da = pd.DataFrame(shyam)
  da.to_csv("channel_rank.csv")
  cr = pd.read_csv("channel_rank.csv")
  sort_channel_name = list(cr["Unnamed: 0"])
  return sort_channel_name

# %% [markdown]
# # Classification

# %%
#Loading the dataset
def svmclassifier(channel_name, status = False):
  channel_names = []
  mypath = "/content/drive/MyDrive/Sequential methods for channel selection/our code/" + subject_name + "/" + subject_name
  data = pd.read_csv(mypath + '.csv')
  for i in range(0, len(channel_name)):
    draft = channel_name[i]
    channel_names.append(draft + "_alpha")
    channel_names.append(draft + "_beta")
    channel_names.append(draft + "_gamma")
    channel_names.append(draft + "_theta")
  x = data[channel_names]
  y = np.array(em_labels)

  # Implementing cross validation
  k = 40
  kf = KFold(n_splits = k, shuffle = status)

  model = svm.SVC(kernel='poly')
  acc_score = []

  for train_index , test_index in kf.split(x):
      x_train , x_test = x.iloc[train_index,:],x.iloc[test_index,:]
      y_train , y_test = y[train_index] , y[test_index]
      model.fit(x_train, y_train)
      pred_values = model.predict(x_test)
      acc = accuracy_score(pred_values , y_test)
      acc_score.append(acc)

  avg_acc_score = sum(acc_score)/k
  #print('accuracy of each fold - {}'.format(acc_score))
  #print('Avg accuracy : {}'.format(avg_acc_score))
  #print(acc_score)
  return avg_acc_score

# %%
def growing_phase(channel_name):
  mypath = "/content/drive/MyDrive/Sequential methods for channel selection/our code/" + subject_name + "/" + subject_name
  data = pd.read_csv(mypath + '.csv')
  cn = channel_name[0]
  acc = svmclassifier([cn])
  cn_list = []
  cn_list.append(cn)
  sort_cn = []
  for i in range(1, len(channel_name)):
    cur_cn = channel_name[i]
    cn_list.append(cur_cn)
    cur_acc = svmclassifier(cn_list)
    if(cur_acc<acc):
      # remove the curent channel name
      #print("Removing channel name: ", cur_cn)
      cn_list.remove(cur_cn)
    else:
      acc = cur_acc
  print("Accuracy in Growing Phase: ", acc)
  print("No of selected channels in Growing Phase: ", len(cn_list))
  print("Channels selected in Growing Phase: ", cn_list)
  return cn_list

# %%
def pruning_phase_get_fscore(optimal_channel_name, subject_name, em_labels):
  ocn = []
  mypath = "/content/drive/MyDrive/Sequential methods for channel selection/our code/" + subject_name + "/" + subject_name
  # for theta band
  data_theta = pd.read_csv(mypath + '_theta.csv')
  # select those particular channels theta band value only
  for i in range(0, len(optimal_channel_name)):
    ocn.append(optimal_channel_name[i] + "_theta")
  draft_theta = data_theta[ocn]
  X, y = np.array(draft_theta), np.array(em_labels)
  f_score_theta = fisher_score(X, y)
  # for alpha band
  data_alpha = pd.read_csv(mypath + '_alpha.csv')
  ocn = []
  # select those particular channels alpha band value only
  for i in range(0, len(optimal_channel_name)):
    ocn.append(optimal_channel_name[i] + "_alpha")
  draft_alpha = data_alpha[ocn]
  X, y = np.array(draft_alpha), np.array(em_labels)
  f_score_alpha = fisher_score(X, y)
  # for beta band
  data_beta = pd.read_csv(mypath + '_beta.csv')
  ocn = []
  # select those particular channels beta band value only
  for i in range(0, len(optimal_channel_name)):
    ocn.append(optimal_channel_name[i] + "_beta")
  draft_beta = data_beta[ocn]
  X, y = np.array(draft_beta), np.array(em_labels)
  f_score_beta = fisher_score(X, y)
  # for gamma band
  data_gamma = pd.read_csv(mypath + '_gamma.csv')
  ocn = []
  # select those particular channels alpha band value only
  for i in range(0, len(optimal_channel_name)):
    ocn.append(optimal_channel_name[i] + "_gamma")
  draft_gamma = data_gamma[ocn]
  X, y = np.array(draft_gamma), np.array(em_labels)
  f_score_gamma = fisher_score(X, y)
  # Total Avearge F-Score (Theta, Alpha, Beta, Gamma)
  final_f_score = (f_score_theta + f_score_alpha + f_score_beta + f_score_gamma)/4
  fvalues = pd.Series(final_f_score)
  fvalues.index = optimal_channel_name
  fvalues.sort_values(ascending=False)
  fvalues.to_csv('fscore_final.csv')
  #fvalues.sort_values(ascending = False).plot.bar(figsize=(10,8))
  shyam = fvalues.sort_values(ascending = False)
  da = pd.DataFrame(shyam)
  da.to_csv("channel_rank.csv")
  cr = pd.read_csv("channel_rank.csv")
  sort_channel_name = list(cr["Unnamed: 0"])
  return sort_channel_name

# %%
def pruning_phase(sort_channel_name):
  # check the accuracy for taking all the channels
  acc = svmclassifier(sort_channel_name)
  if(len(sort_channel_name)==1):
    print("Accuracy in Pruning Phase: ", acc)
    print("No of selected channels in Pruning Phase: ", len(sort_channel_name))
    print("Channels selected in Pruning Phase: ", sort_channel_name)
    return sort_channel_name
  for i in range(0, len(sort_channel_name)):
    cur_cn = sort_channel_name[0:(len(sort_channel_name)-i-1)] # remove for the last channel
    cur_acc = svmclassifier(cur_cn)
    if(cur_acc>acc): # accuracy improved then remove that channel
      acc = cur_acc
      continue
    else: # take that channel
      cur_cn = sort_channel_name[0:(len(sort_channel_name)-i)]
      break
  print("Accuracy in Pruning Phase: ", acc)
  print("No of selected channels in Pruning Phase: ", len(cur_cn))
  print("Channels selected in Pruning Phase: ", cur_cn)
  return cur_cn

# %% [markdown]
# # Test drive Code

# %%
#subject_name = input("Enter the subject name: (for example: 's01'): \n")
#class_label = input("Enter the label ('valence', 'arousal', 'all'): \n")
subject_name = "s02"
class_label = "valence"
link = "/content/drive/MyDrive/Deap/" + subject_name + ".dat"
with open(link, 'rb') as f:
  raw_data = pickle.load(f, encoding = 'latin1')
labels = raw_data['labels']
em_labels = emotion_label(labels, class_label) # get the emotion labels
channel_name = get_fisher_score(subject_name, em_labels)
optimal_channel_name = growing_phase(channel_name)
sort_channel_name = pruning_phase_get_fscore(optimal_channel_name, subject_name, em_labels)
final_channel_name = pruning_phase(sort_channel_name)
# Out:
# Accuracy in Growing Phase:  0.675
# No of selected channels in Growing Phase:  13
# Channels selected in Growing Phase:  ['AF3', 'F4', 'F7', 'CP1', 'O1', 'Fz', 'FC6', 'CP5', 'T7', 'C4', 'FC1', 'P3', 'Fp2']
# Accuracy in Pruning Phase:  0.675
# No of selected channels in Pruning Phase:  13
# Channels selected in Pruning Phase:  ['AF3', 'F4', 'F7', 'CP1', 'O1', 'Fz', 'FC6', 'CP5', 'T7', 'C4', 'FC1', 'P3', 'Fp2']

# %% [markdown]
# # Main Drive Code

# %%
subject_names = ["s01", "s02", "s03", "s04", "s05", "s06", "s07", "s08", "s09", "s10", "s11", "s12", "s13", "s14", "s15", "s16", "s17", "s18", "s19", "s20", "s21",
                "s22", "s23", "s24", "s25", "s26", "s27", "s28", "s29", "s30", "s31", "s32"]
class_labels = ["arousal", "valence", "all"]

# %%
for subject_name in subject_names:
  print("-"*150)
  print("Subject Name: ", subject_name)
  print("-"*150)
  for class_label in class_labels:
    print("Class Label: ", class_label)
    link = "/content/drive/MyDrive/Deap/" + subject_name + ".dat"
    with open(link, 'rb') as f:
      raw_data = pickle.load(f, encoding = 'latin1')
    labels = raw_data['labels']
    em_labels = emotion_label(labels, class_label) # get the emotion labels
    channel_name = get_fisher_score(subject_name, em_labels)
    optimal_channel_name = growing_phase(channel_name)
    sort_channel_name = pruning_phase_get_fscore(optimal_channel_name, subject_name, em_labels)
    final_channel_name = pruning_phase(sort_channel_name)
  print("-"*150)
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s01
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.75
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['P7', 'CP1', 'P3', 'Fz', 'P8', 'FC2', 'F7', 'C4']
# Accuracy in Pruning Phase:  0.75
# No of selected channels in Pruning Phase:  8
# Channels selected in Pruning Phase:  ['P7', 'CP1', 'P3', 'Fz', 'P8', 'FC2', 'F7', 'C4']
# Class Label:  valence
# Accuracy in Growing Phase:  0.675
# No of selected channels in Growing Phase:  5
# Channels selected in Growing Phase:  ['Fz', 'FC2', 'CP6', 'F7', 'FC1']
# Accuracy in Pruning Phase:  0.675
# No of selected channels in Pruning Phase:  5
# Channels selected in Pruning Phase:  ['Fz', 'FC2', 'CP6', 'F7', 'FC1']
# Class Label:  all
# Accuracy in Growing Phase:  0.525
# No of selected channels in Growing Phase:  7
# Channels selected in Growing Phase:  ['P7', 'P8', 'Fz', 'CP6', 'PO3', 'FC5', 'FC1']
# Accuracy in Pruning Phase:  0.525
# No of selected channels in Pruning Phase:  7
# Channels selected in Pruning Phase:  ['P7', 'P8', 'Fz', 'CP6', 'PO3', 'FC5', 'FC1']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s02
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.575
# No of selected channels in Growing Phase:  1
# Channels selected in Growing Phase:  ['FC2']
# Accuracy in Pruning Phase:  0.575
# No of selected channels in Pruning Phase:  1
# Channels selected in Pruning Phase:  ['FC2']
# Class Label:  valence
# Accuracy in Growing Phase:  0.675
# No of selected channels in Growing Phase:  13
# Channels selected in Growing Phase:  ['AF3', 'F4', 'F7', 'CP1', 'O1', 'Fz', 'FC6', 'CP5', 'T7', 'C4', 'FC1', 'P3', 'Fp2']
# Accuracy in Pruning Phase:  0.675
# No of selected channels in Pruning Phase:  13
# Channels selected in Pruning Phase:  ['AF3', 'F4', 'F7', 'CP1', 'O1', 'Fz', 'FC6', 'CP5', 'T7', 'C4', 'FC1', 'P3', 'Fp2']
# Class Label:  all
# Accuracy in Growing Phase:  0.525
# No of selected channels in Growing Phase:  6
# Channels selected in Growing Phase:  ['AF3', 'CP1', 'F7', 'O1', 'AF4', 'FC6']
# Accuracy in Pruning Phase:  0.525
# No of selected channels in Pruning Phase:  6
# Channels selected in Pruning Phase:  ['AF3', 'CP1', 'F7', 'O1', 'AF4', 'FC6']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s03
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.8
# No of selected channels in Growing Phase:  11
# Channels selected in Growing Phase:  ['AF4', 'FC1', 'O2', 'F3', 'AF3', 'P8', 'T7', 'C4', 'Pz', 'FC5', 'PO3']
# Accuracy in Pruning Phase:  0.8
# No of selected channels in Pruning Phase:  11
# Channels selected in Pruning Phase:  ['AF4', 'FC1', 'O2', 'F3', 'AF3', 'P8', 'T7', 'C4', 'Pz', 'FC5', 'PO3']
# Class Label:  valence
# Accuracy in Growing Phase:  0.775
# No of selected channels in Growing Phase:  3
# Channels selected in Growing Phase:  ['O2', 'Oz', 'FC1']
# Accuracy in Pruning Phase:  0.775
# No of selected channels in Pruning Phase:  3
# Channels selected in Pruning Phase:  ['O2', 'Oz', 'FC1']
# Class Label:  all
# Accuracy in Growing Phase:  0.55
# No of selected channels in Growing Phase:  3
# Channels selected in Growing Phase:  ['O2', 'Oz', 'O1']
# Accuracy in Pruning Phase:  0.55
# No of selected channels in Pruning Phase:  3
# Channels selected in Pruning Phase:  ['O2', 'Oz', 'O1']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s04
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.65
# No of selected channels in Growing Phase:  5
# Channels selected in Growing Phase:  ['P8', 'CP2', 'P7', 'Pz', 'P3']
# Accuracy in Pruning Phase:  0.65
# No of selected channels in Pruning Phase:  5
# Channels selected in Pruning Phase:  ['P8', 'CP2', 'P7', 'Pz', 'P3']
# Class Label:  valence
# Accuracy in Growing Phase:  0.675
# No of selected channels in Growing Phase:  3
# Channels selected in Growing Phase:  ['O2', 'CP1', 'PO3']
# Accuracy in Pruning Phase:  0.675
# No of selected channels in Pruning Phase:  3
# Channels selected in Pruning Phase:  ['O2', 'CP1', 'PO3']
# Class Label:  all
# Accuracy in Growing Phase:  0.475
# No of selected channels in Growing Phase:  3
# Channels selected in Growing Phase:  ['P8', 'CP2', 'Cz']
# Accuracy in Pruning Phase:  0.475
# No of selected channels in Pruning Phase:  3
# Channels selected in Pruning Phase:  ['P8', 'CP2', 'Cz']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s05
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.3
# No of selected channels in Growing Phase:  6
# Channels selected in Growing Phase:  ['Fz', 'P7', 'T7', 'CP6', 'O2', 'Fp1']
# Accuracy in Pruning Phase:  0.3
# No of selected channels in Pruning Phase:  6
# Channels selected in Pruning Phase:  ['Fz', 'P7', 'T7', 'CP6', 'O2', 'Fp1']
# Class Label:  valence
# Accuracy in Growing Phase:  0.775
# No of selected channels in Growing Phase:  15
# Channels selected in Growing Phase:  ['C4', 'Cz', 'CP6', 'P7', 'FC6', 'FC2', 'O2', 'F4', 'F7', 'F3', 'Fp1', 'AF3', 'PO3', 'T7', 'AF4']
# Accuracy in Pruning Phase:  0.775
# No of selected channels in Pruning Phase:  15
# Channels selected in Pruning Phase:  ['C4', 'Cz', 'CP6', 'P7', 'FC6', 'FC2', 'O2', 'F4', 'F7', 'F3', 'Fp1', 'AF3', 'PO3', 'T7', 'AF4']
# Class Label:  all
# Accuracy in Growing Phase:  0.3
# No of selected channels in Growing Phase:  14
# Channels selected in Growing Phase:  ['Fz', 'O2', 'PO4', 'FC1', 'F7', 'Oz', 'CP6', 'Fp2', 'FC6', 'C4', 'Pz', 'CP5', 'O1', 'T8']
# Accuracy in Pruning Phase:  0.3
# No of selected channels in Pruning Phase:  14
# Channels selected in Pruning Phase:  ['Fz', 'O2', 'PO4', 'FC1', 'F7', 'Oz', 'CP6', 'Fp2', 'FC6', 'C4', 'Pz', 'CP5', 'O1', 'T8']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s06
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.6
# No of selected channels in Growing Phase:  12
# Channels selected in Growing Phase:  ['C3', 'AF4', 'AF3', 'P7', 'F3', 'F4', 'CP5', 'T8', 'Oz', 'FC6', 'F7', 'Cz']
# Accuracy in Pruning Phase:  0.6
# No of selected channels in Pruning Phase:  12
# Channels selected in Pruning Phase:  ['C3', 'AF4', 'AF3', 'P7', 'F3', 'F4', 'CP5', 'T8', 'Oz', 'FC6', 'F7', 'Cz']
# Class Label:  valence
# Accuracy in Growing Phase:  0.8
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['P4', 'FC6', 'CP2', 'F4', 'O1', 'O2', 'Oz', 'Cz']
# Accuracy in Pruning Phase:  0.8
# No of selected channels in Pruning Phase:  8
# Channels selected in Pruning Phase:  ['P4', 'FC6', 'CP2', 'F4', 'O1', 'O2', 'Oz', 'Cz']
# Class Label:  all
# Accuracy in Growing Phase:  0.425
# No of selected channels in Growing Phase:  4
# Channels selected in Growing Phase:  ['CP1', 'T7', 'FC6', 'AF3']
# Accuracy in Pruning Phase:  0.425
# No of selected channels in Pruning Phase:  4
# Channels selected in Pruning Phase:  ['CP1', 'T7', 'FC6', 'AF3']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s07
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.725
# No of selected channels in Growing Phase:  6
# Channels selected in Growing Phase:  ['FC1', 'F3', 'O1', 'FC5', 'P3', 'Fz']
# Accuracy in Pruning Phase:  0.725
# No of selected channels in Pruning Phase:  6
# Channels selected in Pruning Phase:  ['FC1', 'F3', 'O1', 'FC5', 'P3', 'Fz']
# Class Label:  valence
# Accuracy in Growing Phase:  0.725
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['PO4', 'P4', 'T7', 'FC6', 'F4', 'FC5', 'F7', 'AF3']
# Accuracy in Pruning Phase:  0.725
# No of selected channels in Pruning Phase:  8
# Channels selected in Pruning Phase:  ['PO4', 'P4', 'T7', 'FC6', 'F4', 'FC5', 'F7', 'AF3']
# Class Label:  all
# Accuracy in Growing Phase:  0.45
# No of selected channels in Growing Phase:  9
# Channels selected in Growing Phase:  ['PO4', 'Pz', 'Fp2', 'Cz', 'P8', 'P7', 'O1', 'FC2', 'CP2']
# Accuracy in Pruning Phase:  0.45
# No of selected channels in Pruning Phase:  9
# Channels selected in Pruning Phase:  ['PO4', 'Pz', 'Fp2', 'Cz', 'P8', 'P7', 'O1', 'FC2', 'CP2']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s08
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.65
# No of selected channels in Growing Phase:  9
# Channels selected in Growing Phase:  ['T8', 'Fp1', 'FC6', 'Fp2', 'Fz', 'CP2', 'PO3', 'CP1', 'Cz']
# Accuracy in Pruning Phase:  0.65
# No of selected channels in Pruning Phase:  9
# Channels selected in Pruning Phase:  ['T8', 'Fp1', 'FC6', 'Fp2', 'Fz', 'CP2', 'PO3', 'CP1', 'Cz']
# Class Label:  valence
# Accuracy in Growing Phase:  0.675
# No of selected channels in Growing Phase:  16
# Channels selected in Growing Phase:  ['Fp1', 'P8', 'CP6', 'P7', 'AF3', 'O2', 'C4', 'Pz', 'T8', 'FC2', 'P3', 'AF4', 'PO3', 'Cz', 'CP5', 'Fz']
# Accuracy in Pruning Phase:  0.675
# No of selected channels in Pruning Phase:  16
# Channels selected in Pruning Phase:  ['Fp1', 'P8', 'CP6', 'P7', 'AF3', 'O2', 'C4', 'Pz', 'T8', 'FC2', 'P3', 'AF4', 'PO3', 'Cz', 'CP5', 'Fz']
# Class Label:  all
# Accuracy in Growing Phase:  0.425
# No of selected channels in Growing Phase:  7
# Channels selected in Growing Phase:  ['Fp1', 'CP6', 'O2', 'C4', 'T8', 'AF3', 'PO3']
# Accuracy in Pruning Phase:  0.425
# No of selected channels in Pruning Phase:  7
# Channels selected in Pruning Phase:  ['Fp1', 'CP6', 'O2', 'C4', 'T8', 'AF3', 'PO3']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s09
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.775
# No of selected channels in Growing Phase:  1
# Channels selected in Growing Phase:  ['AF4']
# Accuracy in Pruning Phase:  0.775
# No of selected channels in Pruning Phase:  1
# Channels selected in Pruning Phase:  ['AF4']
# Class Label:  valence
# Accuracy in Growing Phase:  0.8
# No of selected channels in Growing Phase:  4
# Channels selected in Growing Phase:  ['AF4', 'Oz', 'C4', 'F4']
# Accuracy in Pruning Phase:  0.8
# No of selected channels in Pruning Phase:  4
# Channels selected in Pruning Phase:  ['AF4', 'Oz', 'C4', 'F4']
# Class Label:  all
# Accuracy in Growing Phase:  0.55
# No of selected channels in Growing Phase:  5
# Channels selected in Growing Phase:  ['T7', 'AF4', 'T8', 'P8', 'Cz']
# Accuracy in Pruning Phase:  0.55
# No of selected channels in Pruning Phase:  5
# Channels selected in Pruning Phase:  ['T7', 'AF4', 'T8', 'P8', 'Cz']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s10
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.675
# No of selected channels in Growing Phase:  10
# Channels selected in Growing Phase:  ['FC1', 'Fp1', 'CP5', 'P7', 'T8', 'PO4', 'C3', 'PO3', 'F4', 'Cz']
# Accuracy in Pruning Phase:  0.675
# No of selected channels in Pruning Phase:  10
# Channels selected in Pruning Phase:  ['FC1', 'Fp1', 'CP5', 'P7', 'T8', 'PO4', 'C3', 'PO3', 'F4', 'Cz']
# Class Label:  valence
# Accuracy in Growing Phase:  0.675
# No of selected channels in Growing Phase:  3
# Channels selected in Growing Phase:  ['P3', 'CP6', 'FC6']
# Accuracy in Pruning Phase:  0.675
# No of selected channels in Pruning Phase:  3
# Channels selected in Pruning Phase:  ['P3', 'CP6', 'FC6']
# Class Label:  all
# Accuracy in Growing Phase:  0.4
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['T7', 'P3', 'FC1', 'CP1', 'Cz', 'PO3', 'CP2', 'O1']
# Accuracy in Pruning Phase:  0.4
# No of selected channels in Pruning Phase:  8
# Channels selected in Pruning Phase:  ['T7', 'P3', 'FC1', 'CP1', 'Cz', 'PO3', 'CP2', 'O1']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s11
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.725
# No of selected channels in Growing Phase:  1
# Channels selected in Growing Phase:  ['T7']
# Accuracy in Pruning Phase:  0.725
# No of selected channels in Pruning Phase:  1
# Channels selected in Pruning Phase:  ['T7']
# Class Label:  valence
# Accuracy in Growing Phase:  0.6
# No of selected channels in Growing Phase:  4
# Channels selected in Growing Phase:  ['P4', 'F4', 'P7', 'FC2']
# Accuracy in Pruning Phase:  0.6
# No of selected channels in Pruning Phase:  4
# Channels selected in Pruning Phase:  ['P4', 'F4', 'P7', 'FC2']
# Class Label:  all
# Accuracy in Growing Phase:  0.5
# No of selected channels in Growing Phase:  14
# Channels selected in Growing Phase:  ['C3', 'P7', 'FC2', 'F4', 'CP2', 'P3', 'F8', 'FC6', 'F7', 'FC5', 'FC1', 'F3', 'CP5', 'CP1']
# Accuracy in Pruning Phase:  0.5
# No of selected channels in Pruning Phase:  14
# Channels selected in Pruning Phase:  ['C3', 'P7', 'FC2', 'F4', 'CP2', 'P3', 'F8', 'FC6', 'F7', 'FC5', 'FC1', 'F3', 'CP5', 'CP1']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s12
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.85
# No of selected channels in Growing Phase:  5
# Channels selected in Growing Phase:  ['FC6', 'CP5', 'F3', 'Cz', 'FC2']
# Accuracy in Pruning Phase:  0.85
# No of selected channels in Pruning Phase:  5
# Channels selected in Pruning Phase:  ['FC6', 'CP5', 'F3', 'Cz', 'FC2']
# Class Label:  valence
# Accuracy in Growing Phase:  0.725
# No of selected channels in Growing Phase:  3
# Channels selected in Growing Phase:  ['CP1', 'F4', 'F3']
# Accuracy in Pruning Phase:  0.725
# No of selected channels in Pruning Phase:  3
# Channels selected in Pruning Phase:  ['CP1', 'F4', 'F3']
# Class Label:  all
# Accuracy in Growing Phase:  0.675
# No of selected channels in Growing Phase:  4
# Channels selected in Growing Phase:  ['Cz', 'P3', 'F3', 'AF3']
# Accuracy in Pruning Phase:  0.675
# No of selected channels in Pruning Phase:  4
# Channels selected in Pruning Phase:  ['Cz', 'P3', 'F3', 'AF3']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s13
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.875
# No of selected channels in Growing Phase:  3
# Channels selected in Growing Phase:  ['PO3', 'P7', 'Fp2']
# Accuracy in Pruning Phase:  0.875
# No of selected channels in Pruning Phase:  3
# Channels selected in Pruning Phase:  ['PO3', 'P7', 'Fp2']
# Class Label:  valence
# Accuracy in Growing Phase:  0.85
# No of selected channels in Growing Phase:  7
# Channels selected in Growing Phase:  ['Cz', 'Fp2', 'Pz', 'AF3', 'FC2', 'P4', 'F7']
# Accuracy in Pruning Phase:  0.85
# No of selected channels in Pruning Phase:  7
# Channels selected in Pruning Phase:  ['Cz', 'Fp2', 'Pz', 'AF3', 'FC2', 'P4', 'F7']
# Class Label:  all
# Accuracy in Growing Phase:  0.725
# No of selected channels in Growing Phase:  13
# Channels selected in Growing Phase:  ['Cz', 'AF3', 'Pz', 'Fp2', 'Oz', 'P4', 'Fz', 'FC2', 'AF4', 'P8', 'F8', 'P7', 'CP1']
# Accuracy in Pruning Phase:  0.725
# No of selected channels in Pruning Phase:  13
# Channels selected in Pruning Phase:  ['Cz', 'AF3', 'Pz', 'Fp2', 'Oz', 'P4', 'Fz', 'FC2', 'AF4', 'P8', 'F8', 'P7', 'CP1']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s14
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.75
# No of selected channels in Growing Phase:  10
# Channels selected in Growing Phase:  ['PO3', 'FC2', 'P3', 'AF3', 'CP5', 'Pz', 'F7', 'T7', 'O2', 'F3']
# Accuracy in Pruning Phase:  0.75
# No of selected channels in Pruning Phase:  10
# Channels selected in Pruning Phase:  ['PO3', 'FC2', 'P3', 'AF3', 'CP5', 'Pz', 'F7', 'T7', 'O2', 'F3']
# Class Label:  valence
# Accuracy in Growing Phase:  0.8
# No of selected channels in Growing Phase:  6
# Channels selected in Growing Phase:  ['FC2', 'P3', 'F8', 'P8', 'FC5', 'AF4']
# Accuracy in Pruning Phase:  0.8
# No of selected channels in Pruning Phase:  6
# Channels selected in Pruning Phase:  ['FC2', 'P3', 'F8', 'P8', 'FC5', 'AF4']
# Class Label:  all
# Accuracy in Growing Phase:  0.6
# No of selected channels in Growing Phase:  3
# Channels selected in Growing Phase:  ['FC2', 'PO3', 'P7']
# Accuracy in Pruning Phase:  0.6
# No of selected channels in Pruning Phase:  3
# Channels selected in Pruning Phase:  ['FC2', 'PO3', 'P7']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s15
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.775
# No of selected channels in Growing Phase:  12
# Channels selected in Growing Phase:  ['FC2', 'FC1', 'Fz', 'P3', 'AF4', 'Cz', 'CP1', 'CP2', 'Fp2', 'AF3', 'CP5', 'Pz']
# Accuracy in Pruning Phase:  0.775
# No of selected channels in Pruning Phase:  12
# Channels selected in Pruning Phase:  ['FC2', 'FC1', 'Fz', 'P3', 'AF4', 'Cz', 'CP1', 'CP2', 'Fp2', 'AF3', 'CP5', 'Pz']
# Class Label:  valence
# Accuracy in Growing Phase:  0.725
# No of selected channels in Growing Phase:  2
# Channels selected in Growing Phase:  ['Pz', 'AF3']
# Accuracy in Pruning Phase:  0.725
# No of selected channels in Pruning Phase:  2
# Channels selected in Pruning Phase:  ['Pz', 'AF3']
# Class Label:  all
# Accuracy in Growing Phase:  0.4
# No of selected channels in Growing Phase:  6
# Channels selected in Growing Phase:  ['Pz', 'FC6', 'P4', 'Fp1', 'PO3', 'AF3']
# Accuracy in Pruning Phase:  0.4
# No of selected channels in Pruning Phase:  6
# Channels selected in Pruning Phase:  ['Pz', 'FC6', 'P4', 'Fp1', 'PO3', 'AF3']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s16
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.775
# No of selected channels in Growing Phase:  5
# Channels selected in Growing Phase:  ['O2', 'FC1', 'C3', 'C4', 'Cz']
# Accuracy in Pruning Phase:  0.775
# No of selected channels in Pruning Phase:  5
# Channels selected in Pruning Phase:  ['O2', 'FC1', 'C3', 'C4', 'Cz']
# Class Label:  valence
# Accuracy in Growing Phase:  0.65
# No of selected channels in Growing Phase:  24
# Channels selected in Growing Phase:  ['FC6', 'Fp1', 'Fp2', 'Cz', 'P4', 'P3', 'PO3', 'Oz', 'C4', 'CP2', 'F3', 'CP1', 'O1', 'P8', 'T8', 'C3', 'PO4', 'Pz', 'Fz', 'F8', 'FC2', 'CP6', 'F4', 'P7']
# Accuracy in Pruning Phase:  0.65
# No of selected channels in Pruning Phase:  24
# Channels selected in Pruning Phase:  ['FC6', 'Fp1', 'Fp2', 'Cz', 'P4', 'P3', 'PO3', 'Oz', 'C4', 'CP2', 'F3', 'CP1', 'O1', 'P8', 'T8', 'C3', 'PO4', 'Pz', 'Fz', 'F8', 'FC2', 'CP6', 'F4', 'P7']
# Class Label:  all
# Accuracy in Growing Phase:  0.575
# No of selected channels in Growing Phase:  3
# Channels selected in Growing Phase:  ['O2', 'FC1', 'T8']
# Accuracy in Pruning Phase:  0.575
# No of selected channels in Pruning Phase:  3
# Channels selected in Pruning Phase:  ['O2', 'FC1', 'T8']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s17
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.825
# No of selected channels in Growing Phase:  4
# Channels selected in Growing Phase:  ['P4', 'CP2', 'FC2', 'Fp1']
# Accuracy in Pruning Phase:  0.825
# No of selected channels in Pruning Phase:  4
# Channels selected in Pruning Phase:  ['P4', 'CP2', 'FC2', 'Fp1']
# Class Label:  valence
# Accuracy in Growing Phase:  0.65
# No of selected channels in Growing Phase:  4
# Channels selected in Growing Phase:  ['F8', 'P3', 'PO3', 'CP1']
# Accuracy in Pruning Phase:  0.65
# No of selected channels in Pruning Phase:  4
# Channels selected in Pruning Phase:  ['F8', 'P3', 'PO3', 'CP1']
# Class Label:  all
# Accuracy in Growing Phase:  0.5
# No of selected channels in Growing Phase:  10
# Channels selected in Growing Phase:  ['CP1', 'CP6', 'T8', 'AF4', 'PO4', 'O2', 'Pz', 'O1', 'F4', 'C4']
# Accuracy in Pruning Phase:  0.5
# No of selected channels in Pruning Phase:  10
# Channels selected in Pruning Phase:  ['CP1', 'CP6', 'T8', 'AF4', 'PO4', 'O2', 'Pz', 'O1', 'F4', 'C4']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s18
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.7
# No of selected channels in Growing Phase:  6
# Channels selected in Growing Phase:  ['AF4', 'FC6', 'FC5', 'PO4', 'P3', 'CP1']
# Accuracy in Pruning Phase:  0.7
# No of selected channels in Pruning Phase:  6
# Channels selected in Pruning Phase:  ['AF4', 'FC6', 'FC5', 'PO4', 'P3', 'CP1']
# Class Label:  valence
# Accuracy in Growing Phase:  0.8
# No of selected channels in Growing Phase:  13
# Channels selected in Growing Phase:  ['FC6', 'AF4', 'FC1', 'Pz', 'Oz', 'C3', 'F8', 'CP1', 'T7', 'Cz', 'PO4', 'Fp1', 'F7']
# Accuracy in Pruning Phase:  0.8
# No of selected channels in Pruning Phase:  13
# Channels selected in Pruning Phase:  ['FC6', 'AF4', 'FC1', 'Pz', 'Oz', 'C3', 'F8', 'CP1', 'T7', 'Cz', 'PO4', 'Fp1', 'F7']
# Class Label:  all
# Accuracy in Growing Phase:  0.55
# No of selected channels in Growing Phase:  5
# Channels selected in Growing Phase:  ['FC6', 'AF4', 'Pz', 'F8', 'O1']
# Accuracy in Pruning Phase:  0.55
# No of selected channels in Pruning Phase:  5
# Channels selected in Pruning Phase:  ['FC6', 'AF4', 'Pz', 'F8', 'O1']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s19
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.725
# No of selected channels in Growing Phase:  12
# Channels selected in Growing Phase:  ['CP5', 'P8', 'C4', 'FC6', 'PO4', 'O2', 'P4', 'CP6', 'P7', 'CP2', 'PO3', 'FC2']
# Accuracy in Pruning Phase:  0.725
# No of selected channels in Pruning Phase:  12
# Channels selected in Pruning Phase:  ['CP5', 'P8', 'C4', 'FC6', 'PO4', 'O2', 'P4', 'CP6', 'P7', 'CP2', 'PO3', 'FC2']
# Class Label:  valence
# Accuracy in Growing Phase:  0.775
# No of selected channels in Growing Phase:  4
# Channels selected in Growing Phase:  ['C4', 'F3', 'CP6', 'FC6']
# Accuracy in Pruning Phase:  0.775
# No of selected channels in Pruning Phase:  4
# Channels selected in Pruning Phase:  ['C4', 'F3', 'CP6', 'FC6']
# Class Label:  all
# Accuracy in Growing Phase:  0.4
# No of selected channels in Growing Phase:  4
# Channels selected in Growing Phase:  ['P8', 'CP6', 'T8', 'F4']
# Accuracy in Pruning Phase:  0.4
# No of selected channels in Pruning Phase:  4
# Channels selected in Pruning Phase:  ['P8', 'CP6', 'T8', 'F4']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s20
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.85
# No of selected channels in Growing Phase:  17
# Channels selected in Growing Phase:  ['F3', 'P7', 'CP6', 'F4', 'FC6', 'F8', 'CP5', 'Fz', 'T7', 'FC5', 'AF3', 'O1', 'CP1', 'Cz', 'F7', 'C3', 'FC1']
# Accuracy in Pruning Phase:  0.85
# No of selected channels in Pruning Phase:  17
# Channels selected in Pruning Phase:  ['F3', 'P7', 'CP6', 'F4', 'FC6', 'F8', 'CP5', 'Fz', 'T7', 'FC5', 'AF3', 'O1', 'CP1', 'Cz', 'F7', 'C3', 'FC1']
# Class Label:  valence
# Accuracy in Growing Phase:  0.75
# No of selected channels in Growing Phase:  1
# Channels selected in Growing Phase:  ['AF4']
# Accuracy in Pruning Phase:  0.75
# No of selected channels in Pruning Phase:  1
# Channels selected in Pruning Phase:  ['AF4']
# Class Label:  all
# Accuracy in Growing Phase:  0.675
# No of selected channels in Growing Phase:  13
# Channels selected in Growing Phase:  ['AF4', 'Fz', 'PO3', 'FC2', 'CP5', 'F8', 'P4', 'T7', 'F7', 'Fp2', 'FC5', 'PO4', 'C3']
# Accuracy in Pruning Phase:  0.675
# No of selected channels in Pruning Phase:  13
# Channels selected in Pruning Phase:  ['AF4', 'Fz', 'PO3', 'FC2', 'CP5', 'F8', 'P4', 'T7', 'F7', 'Fp2', 'FC5', 'PO4', 'C3']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s21
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.85
# No of selected channels in Growing Phase:  2
# Channels selected in Growing Phase:  ['P4', 'Fz']
# Accuracy in Pruning Phase:  0.85
# No of selected channels in Pruning Phase:  2
# Channels selected in Pruning Phase:  ['P4', 'Fz']
# Class Label:  valence
# Accuracy in Growing Phase:  0.725
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['AF3', 'P3', 'F4', 'PO4', 'Oz', 'CP2', 'AF4', 'T8']
# Accuracy in Pruning Phase:  0.725
# No of selected channels in Pruning Phase:  8
# Channels selected in Pruning Phase:  ['AF3', 'P3', 'F4', 'PO4', 'Oz', 'CP2', 'AF4', 'T8']
# Class Label:  all
# Accuracy in Growing Phase:  0.45
# No of selected channels in Growing Phase:  6
# Channels selected in Growing Phase:  ['P7', 'T8', 'P4', 'Fz', 'F8', 'Fp2']
# Accuracy in Pruning Phase:  0.45
# No of selected channels in Pruning Phase:  6
# Channels selected in Pruning Phase:  ['P7', 'T8', 'P4', 'Fz', 'F8', 'Fp2']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s22
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.7
# No of selected channels in Growing Phase:  7
# Channels selected in Growing Phase:  ['O1', 'CP2', 'FC1', 'CP1', 'CP6', 'F8', 'P8']
# Accuracy in Pruning Phase:  0.7
# No of selected channels in Pruning Phase:  7
# Channels selected in Pruning Phase:  ['O1', 'CP2', 'FC1', 'CP1', 'CP6', 'F8', 'P8']
# Class Label:  valence
# Accuracy in Growing Phase:  0.675
# No of selected channels in Growing Phase:  15
# Channels selected in Growing Phase:  ['C3', 'T8', 'P4', 'PO3', 'Fp2', 'AF4', 'C4', 'Fp1', 'F4', 'AF3', 'CP5', 'FC2', 'FC5', 'FC1', 'Oz']
# Accuracy in Pruning Phase:  0.675
# No of selected channels in Pruning Phase:  15
# Channels selected in Pruning Phase:  ['C3', 'T8', 'P4', 'PO3', 'Fp2', 'AF4', 'C4', 'Fp1', 'F4', 'AF3', 'CP5', 'FC2', 'FC5', 'FC1', 'Oz']
# Class Label:  all
# Accuracy in Growing Phase:  0.475
# No of selected channels in Growing Phase:  12
# Channels selected in Growing Phase:  ['O2', 'C3', 'P4', 'PO4', 'F3', 'PO3', 'Fz', 'Fp2', 'AF4', 'T8', 'Fp1', 'CP1']
# Accuracy in Pruning Phase:  0.475
# No of selected channels in Pruning Phase:  12
# Channels selected in Pruning Phase:  ['O2', 'C3', 'P4', 'PO4', 'F3', 'PO3', 'Fz', 'Fp2', 'AF4', 'T8', 'Fp1', 'CP1']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s23
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.85
# No of selected channels in Growing Phase:  5
# Channels selected in Growing Phase:  ['Fp1', 'F3', 'CP5', 'Cz', 'FC5']
# Accuracy in Pruning Phase:  0.85
# No of selected channels in Pruning Phase:  5
# Channels selected in Pruning Phase:  ['Fp1', 'F3', 'CP5', 'Cz', 'FC5']
# Class Label:  valence
# Accuracy in Growing Phase:  0.75
# No of selected channels in Growing Phase:  4
# Channels selected in Growing Phase:  ['T8', 'P4', 'F4', 'AF3']
# Accuracy in Pruning Phase:  0.75
# No of selected channels in Pruning Phase:  4
# Channels selected in Pruning Phase:  ['T8', 'P4', 'F4', 'AF3']
# Class Label:  all
# Accuracy in Growing Phase:  0.575
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['T7', 'Fp1', 'CP5', 'P8', 'F7', 'F8', 'AF4', 'FC2']
# Accuracy in Pruning Phase:  0.575
# No of selected channels in Pruning Phase:  8
# Channels selected in Pruning Phase:  ['T7', 'Fp1', 'CP5', 'P8', 'F7', 'F8', 'AF4', 'FC2']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s24
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.825
# No of selected channels in Growing Phase:  32
# Channels selected in Growing Phase:  ['Pz', 'O2', 'P8', 'CP2', 'O1', 'PO3', 'F8', 'FC1', 'P3', 'CP1', 'Cz', 'T8', 'FC2', 'C3', 'FC5', 'Fz', 'CP5', 'F4', 'PO4', 'F7', 'Oz', 'T7', 'P7', 'AF4', 'Fp2', 'FC6', 'F3', 'P4', 'Fp1', 'AF3', 'C4', 'CP6']
# Accuracy in Pruning Phase:  0.825
# No of selected channels in Pruning Phase:  32
# Channels selected in Pruning Phase:  ['Pz', 'O2', 'P8', 'CP2', 'O1', 'PO3', 'F8', 'FC1', 'P3', 'CP1', 'Cz', 'T8', 'FC2', 'C3', 'FC5', 'Fz', 'CP5', 'F4', 'PO4', 'F7', 'Oz', 'T7', 'P7', 'AF4', 'Fp2', 'FC6', 'F3', 'P4', 'Fp1', 'AF3', 'C4', 'CP6']
# Class Label:  valence
# Accuracy in Growing Phase:  0.575
# No of selected channels in Growing Phase:  3
# Channels selected in Growing Phase:  ['FC1', 'Pz', 'PO3']
# Accuracy in Pruning Phase:  0.575
# No of selected channels in Pruning Phase:  3
# Channels selected in Pruning Phase:  ['FC1', 'Pz', 'PO3']
# Class Label:  all
# Accuracy in Growing Phase:  0.5
# No of selected channels in Growing Phase:  21
# Channels selected in Growing Phase:  ['Pz', 'P8', 'CP2', 'O1', 'P3', 'CP1', 'Cz', 'C3', 'FC2', 'T7', 'Oz', 'P7', 'AF4', 'Fp2', 'FC6', 'F3', 'P4', 'Fp1', 'C4', 'AF3', 'CP6']
# Accuracy in Pruning Phase:  0.5
# No of selected channels in Pruning Phase:  21
# Channels selected in Pruning Phase:  ['Pz', 'P8', 'CP2', 'O1', 'P3', 'CP1', 'Cz', 'C3', 'FC2', 'T7', 'Oz', 'P7', 'AF4', 'Fp2', 'FC6', 'F3', 'P4', 'Fp1', 'C4', 'AF3', 'CP6']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s25
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.725
# No of selected channels in Growing Phase:  1
# Channels selected in Growing Phase:  ['FC2']
# Accuracy in Pruning Phase:  0.725
# No of selected channels in Pruning Phase:  1
# Channels selected in Pruning Phase:  ['FC2']
# Class Label:  valence
# Accuracy in Growing Phase:  0.65
# No of selected channels in Growing Phase:  2
# Channels selected in Growing Phase:  ['FC2', 'Fp2']
# Accuracy in Pruning Phase:  0.65
# No of selected channels in Pruning Phase:  2
# Channels selected in Pruning Phase:  ['FC2', 'Fp2']
# Class Label:  all
# Accuracy in Growing Phase:  0.525
# No of selected channels in Growing Phase:  3
# Channels selected in Growing Phase:  ['FC2', 'FC5', 'F4']
# Accuracy in Pruning Phase:  0.525
# No of selected channels in Pruning Phase:  3
# Channels selected in Pruning Phase:  ['FC2', 'FC5', 'F4']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s26
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.7
# No of selected channels in Growing Phase:  7
# Channels selected in Growing Phase:  ['AF4', 'FC5', 'CP5', 'Oz', 'FC2', 'C3', 'Cz']
# Accuracy in Pruning Phase:  0.7
# No of selected channels in Pruning Phase:  7
# Channels selected in Pruning Phase:  ['AF4', 'FC5', 'CP5', 'Oz', 'FC2', 'C3', 'Cz']
# Class Label:  valence
# Accuracy in Growing Phase:  0.725
# No of selected channels in Growing Phase:  6
# Channels selected in Growing Phase:  ['Pz', 'P3', 'FC2', 'FC1', 'P7', 'T7']
# Accuracy in Pruning Phase:  0.725
# No of selected channels in Pruning Phase:  6
# Channels selected in Pruning Phase:  ['Pz', 'P3', 'FC2', 'FC1', 'P7', 'T7']
# Class Label:  all
# Accuracy in Growing Phase:  0.575
# No of selected channels in Growing Phase:  2
# Channels selected in Growing Phase:  ['P3', 'FC5']
# Accuracy in Pruning Phase:  0.575
# No of selected channels in Pruning Phase:  2
# Channels selected in Pruning Phase:  ['P3', 'FC5']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s27
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.65
# No of selected channels in Growing Phase:  11
# Channels selected in Growing Phase:  ['PO3', 'Oz', 'AF4', 'CP6', 'F8', 'Cz', 'FC6', 'O1', 'P8', 'F4', 'Fp2']
# Accuracy in Pruning Phase:  0.65
# No of selected channels in Pruning Phase:  11
# Channels selected in Pruning Phase:  ['PO3', 'Oz', 'AF4', 'CP6', 'F8', 'Cz', 'FC6', 'O1', 'P8', 'F4', 'Fp2']
# Class Label:  valence
# Accuracy in Growing Phase:  0.75
# No of selected channels in Growing Phase:  22
# Channels selected in Growing Phase:  ['Oz', 'FC5', 'CP6', 'O2', 'C4', 'CP2', 'FC6', 'F3', 'C3', 'P3', 'CP5', 'P4', 'Cz', 'PO4', 'FC1', 'Pz', 'O1', 'Fz', 'T7', 'FC2', 'P7', 'Fp2']
# Accuracy in Pruning Phase:  0.75
# No of selected channels in Pruning Phase:  22
# Channels selected in Pruning Phase:  ['Oz', 'FC5', 'CP6', 'O2', 'C4', 'CP2', 'FC6', 'F3', 'C3', 'P3', 'CP5', 'P4', 'Cz', 'PO4', 'FC1', 'Pz', 'O1', 'Fz', 'T7', 'FC2', 'P7', 'Fp2']
# Class Label:  all
# Accuracy in Growing Phase:  0.6
# No of selected channels in Growing Phase:  19
# Channels selected in Growing Phase:  ['Oz', 'T8', 'AF4', 'FC5', 'CP6', 'FC6', 'CP5', 'O2', 'CP1', 'F7', 'C4', 'F3', 'CP2', 'C3', 'P4', 'F8', 'T7', 'Cz', 'Fz']
# Accuracy in Pruning Phase:  0.6
# No of selected channels in Pruning Phase:  19
# Channels selected in Pruning Phase:  ['Oz', 'T8', 'AF4', 'FC5', 'CP6', 'FC6', 'CP5', 'O2', 'CP1', 'F7', 'C4', 'F3', 'CP2', 'C3', 'P4', 'F8', 'T7', 'Cz', 'Fz']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s28
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.7
# No of selected channels in Growing Phase:  8
# Channels selected in Growing Phase:  ['PO3', 'F4', 'FC6', 'Oz', 'CP2', 'O2', 'P4', 'CP6']
# Accuracy in Pruning Phase:  0.7
# No of selected channels in Pruning Phase:  8
# Channels selected in Pruning Phase:  ['PO3', 'F4', 'FC6', 'Oz', 'CP2', 'O2', 'P4', 'CP6']
# Class Label:  valence
# Accuracy in Growing Phase:  0.7
# No of selected channels in Growing Phase:  12
# Channels selected in Growing Phase:  ['C3', 'CP2', 'F3', 'O1', 'CP1', 'Pz', 'Oz', 'PO4', 'O2', 'P4', 'P8', 'CP5']
# Accuracy in Pruning Phase:  0.7
# No of selected channels in Pruning Phase:  12
# Channels selected in Pruning Phase:  ['C3', 'CP2', 'F3', 'O1', 'CP1', 'Pz', 'Oz', 'PO4', 'O2', 'P4', 'P8', 'CP5']
# Class Label:  all
# Accuracy in Growing Phase:  0.45
# No of selected channels in Growing Phase:  18
# Channels selected in Growing Phase:  ['CP2', 'C3', 'Oz', 'FC1', 'Pz', 'O2', 'PO4', 'P4', 'Fz', 'P8', 'CP5', 'PO3', 'Fp1', 'FC6', 'AF4', 'Fp2', 'C4', 'CP6']
# Accuracy in Pruning Phase:  0.45
# No of selected channels in Pruning Phase:  18
# Channels selected in Pruning Phase:  ['CP2', 'C3', 'Oz', 'FC1', 'Pz', 'O2', 'PO4', 'P4', 'Fz', 'P8', 'CP5', 'PO3', 'Fp1', 'FC6', 'AF4', 'Fp2', 'C4', 'CP6']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s29
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.725
# No of selected channels in Growing Phase:  10
# Channels selected in Growing Phase:  ['O2', 'CP6', 'Cz', 'PO4', 'O1', 'FC1', 'T8', 'P4', 'F4', 'C3']
# Accuracy in Pruning Phase:  0.725
# No of selected channels in Pruning Phase:  10
# Channels selected in Pruning Phase:  ['O2', 'CP6', 'Cz', 'PO4', 'O1', 'FC1', 'T8', 'P4', 'F4', 'C3']
# Class Label:  valence
# Accuracy in Growing Phase:  0.775
# No of selected channels in Growing Phase:  11
# Channels selected in Growing Phase:  ['AF3', 'Cz', 'CP6', 'P4', 'Fp1', 'F8', 'F3', 'P7', 'FC6', 'F4', 'AF4']
# Accuracy in Pruning Phase:  0.775
# No of selected channels in Pruning Phase:  11
# Channels selected in Pruning Phase:  ['AF3', 'Cz', 'CP6', 'P4', 'Fp1', 'F8', 'F3', 'P7', 'FC6', 'F4', 'AF4']
# Class Label:  all
# Accuracy in Growing Phase:  0.55
# No of selected channels in Growing Phase:  7
# Channels selected in Growing Phase:  ['AF3', 'CP6', 'O2', 'F8', 'O1', 'CP1', 'CP5']
# Accuracy in Pruning Phase:  0.55
# No of selected channels in Pruning Phase:  7
# Channels selected in Pruning Phase:  ['AF3', 'CP6', 'O2', 'F8', 'O1', 'CP1', 'CP5']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s30
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.65
# No of selected channels in Growing Phase:  24
# Channels selected in Growing Phase:  ['Oz', 'P4', 'CP1', 'P3', 'FC6', 'AF3', 'F3', 'F7', 'CP2', 'Cz', 'CP5', 'C4', 'FC1', 'P8', 'T8', 'T7', 'F8', 'C3', 'O2', 'CP6', 'Fp1', 'AF4', 'O1', 'F4']
# Accuracy in Pruning Phase:  0.65
# No of selected channels in Pruning Phase:  24
# Channels selected in Pruning Phase:  ['Oz', 'P4', 'CP1', 'P3', 'FC6', 'AF3', 'F3', 'F7', 'CP2', 'Cz', 'CP5', 'C4', 'FC1', 'P8', 'T8', 'T7', 'F8', 'C3', 'O2', 'CP6', 'Fp1', 'AF4', 'O1', 'F4']
# Class Label:  valence
# Accuracy in Growing Phase:  0.675
# No of selected channels in Growing Phase:  14
# Channels selected in Growing Phase:  ['PO4', 'Fz', 'Cz', 'AF3', 'FC2', 'Oz', 'P4', 'FC1', 'Fp2', 'O1', 'O2', 'Fp1', 'C3', 'T7']
# Accuracy in Pruning Phase:  0.675
# No of selected channels in Pruning Phase:  14
# Channels selected in Pruning Phase:  ['PO4', 'Fz', 'Cz', 'AF3', 'FC2', 'Oz', 'P4', 'FC1', 'Fp2', 'O1', 'O2', 'Fp1', 'C3', 'T7']
# Class Label:  all
# Accuracy in Growing Phase:  0.3
# No of selected channels in Growing Phase:  2
# Channels selected in Growing Phase:  ['Oz', 'PO4']
# Accuracy in Pruning Phase:  0.3
# No of selected channels in Pruning Phase:  2
# Channels selected in Pruning Phase:  ['Oz', 'PO4']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s31
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.75
# No of selected channels in Growing Phase:  11
# Channels selected in Growing Phase:  ['FC2', 'C4', 'PO4', 'P4', 'F4', 'FC1', 'C3', 'CP6', 'AF3', 'F7', 'FC5']
# Accuracy in Pruning Phase:  0.75
# No of selected channels in Pruning Phase:  11
# Channels selected in Pruning Phase:  ['FC2', 'C4', 'PO4', 'P4', 'F4', 'FC1', 'C3', 'CP6', 'AF3', 'F7', 'FC5']
# Class Label:  valence
# Accuracy in Growing Phase:  0.725
# No of selected channels in Growing Phase:  4
# Channels selected in Growing Phase:  ['CP6', 'CP2', 'Cz', 'CP5']
# Accuracy in Pruning Phase:  0.725
# No of selected channels in Pruning Phase:  4
# Channels selected in Pruning Phase:  ['CP6', 'CP2', 'Cz', 'CP5']
# Class Label:  all
# Accuracy in Growing Phase:  0.525
# No of selected channels in Growing Phase:  2
# Channels selected in Growing Phase:  ['C4', 'F4']
# Accuracy in Pruning Phase:  0.525
# No of selected channels in Pruning Phase:  2
# Channels selected in Pruning Phase:  ['C4', 'F4']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Subject Name:  s32
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Class Label:  arousal
# Accuracy in Growing Phase:  0.7
# No of selected channels in Growing Phase:  7
# Channels selected in Growing Phase:  ['Fz', 'Cz', 'P7', 'F4', 'F8', 'C4', 'P4']
# Accuracy in Pruning Phase:  0.7
# No of selected channels in Pruning Phase:  7
# Channels selected in Pruning Phase:  ['Fz', 'Cz', 'P7', 'F4', 'F8', 'C4', 'P4']
# Class Label:  valence
# Accuracy in Growing Phase:  0.675
# No of selected channels in Growing Phase:  13
# Channels selected in Growing Phase:  ['CP2', 'O1', 'O2', 'CP6', 'CP5', 'PO4', 'FC6', 'P8', 'FC1', 'AF3', 'Cz', 'Oz', 'Fp1']
# Accuracy in Pruning Phase:  0.675
# No of selected channels in Pruning Phase:  13
# Channels selected in Pruning Phase:  ['CP2', 'O1', 'O2', 'CP6', 'CP5', 'PO4', 'FC6', 'P8', 'FC1', 'AF3', 'Cz', 'Oz', 'Fp1']
# Class Label:  all
# Accuracy in Growing Phase:  0.425
# No of selected channels in Growing Phase:  9
# Channels selected in Growing Phase:  ['CP6', 'CP2', 'CP5', 'O1', 'PO4', 'Fz', 'AF4', 'Cz', 'Oz']
# Accuracy in Pruning Phase:  0.425
# No of selected channels in Pruning Phase:  9
# Channels selected in Pruning Phase:  ['CP6', 'CP2', 'CP5', 'O1', 'PO4', 'Fz', 'AF4', 'Cz', 'Oz']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
